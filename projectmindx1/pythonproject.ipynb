# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\PC\AppData\Roaming\Python\Python37\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# **XỬ LÝ BẢNG APPLICATION-BANKING**

# %%
# đọc file Applications-Banking
df_application = pd.read_excel(r'D:\mindxdata\banking application\Applications-Banking.xlsx')
df_application
# Out:
#     Application ID      Application Type Customer ID Group Name ID    Action  \
# 0           ID1148                Dealer      IFR153        GRP507  Existing
# 1           ID1292                Dealer      IFR177        GRP516  Existing
# 2           ID1193                Dealer      IFR117        GRP501       New
# 3           ID1197                Dealer      IFR193        GRP516  Straight
# 4           ID1054                Dealer      IFR157        GRP515       New
# ..             ...                   ...         ...           ...       ...
# 495         ID1406                Dealer      IFR188        GRP515       New
# 496         ID1423  Property Development      IFR198        GRP511  Existing
# 497         ID1211             Corporate      IFR137        GRP505  Existing
# 498         ID1238             Corporate      IFR109        GRP505       New
# 499         ID1338                Dealer      IFR186        GRP502       New
#
# ...

# %%
#tìm missing
df_application.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Application ID          500 non-null    object
#  1   Application Type        500 non-null    object
#  2   Customer ID             500 non-null    object
#  3   Group Name ID           500 non-null    object
#  4   Action                  500 non-null    object
#  5   RM ID                   500 non-null    object
#  6   Entered Date            500 non-null    datetime64[ns]
#  7   Closed Date             500 non-null    datetime64[ns]
#  8   Next Review Date        500 non-null    datetime64[ns]
#  9   Product ID              500 non-null    object
#  10  Start Date              500 non-null    datetime64[ns]
#  11  Term (mths)             500 non-null    int64
#  12  Expiry Date             500 non-null    datetime64[ns]
# ...

# %% [markdown]
# => DataFrame không có missing

# %%
df_application.describe()
# Out:
#        Term (mths)  Rate Applied  Margin Agreed       Capital  \
# count   500.000000    500.000000     500.000000  5.000000e+02
# mean     23.172000      2.644260       0.303620  3.632040e+06
# std      15.743256      0.631567       0.117538  1.993167e+06
# min       6.000000      1.500000       0.100000  1.700000e+05
# 25%      12.000000      2.087500       0.207500  1.857500e+06
# 50%      24.000000      2.645000       0.300000  3.765000e+06
# 75%      36.000000      3.200000       0.410000  5.375000e+06
# max      60.000000      3.750000       0.500000  7.000000e+06
#
#        Annual Interest Income    Face Value  Conversion Factor      Rating  \
# count              500.000000  5.000000e+02         500.000000  500.000000
# mean            106098.186000  1.323280e+07           0.761700    3.566000
# std              62974.092354  6.265966e+06           0.172678    1.728473
# min               4984.000000  2.100000e+06           0.400000    1.000000
# ...

# %%
#xóa cột không cần thiết trong bảng application (Action, Collateral Start Date, Conversion Factor,Covenant Type,Limits Rating, Rating,Expected Loss,Covenants,Application Error)
columns = ['Action', 'Collateral Start Date', 'Conversion Factor','Covenant Type','Limits Rating','Expected Loss','Covenants','Application Error']
df_application.drop(columns, inplace =True, axis=1)

# %%
#xuất ra file csv đặt tên thành application1
df_application.to_csv("D:\\mindxdata\\application_banking.csv")

# %% [markdown]
# **XỬ LÝ BẢNG CUSTOMERS-BANKING**

# %%
#đọc bảng customer-banking
df_customer = pd.read_excel('D:\\mindxdata\\banking application\customer-banking.xlsx')
df_customer
# Out:
#    Customer ID     Customer Name Group ID      Group Name  \
# 0       IFR100     Geiss Company   GRP500     Ventura Ltd
# 1       IFR101     Jaxbean Group   GRP504         Kroger
# 2       IFR102        Ascend Ltd   GRP512  Aurobindo Corp
# 3       IFR103         Eire Corp   GRP505        TYA Corp
# 4       IFR104      Blogtags Ltd   GRP502        Rite Ltd
# ..         ...               ...      ...             ...
# 95      IFR195    Dentsply Group   GRP517   Wal-Mart Corp
# 96      IFR196         EKR Group   GRP500     Ventura Ltd
# 97      IFR197              MSC    GRP502        Rite Ltd
# 98      IFR198         Dong Corp   GRP511  Physicians Ltd
# 99      IFR199  Mechanical Group   GRP514          Hikma
#
#    Relationship Established  Customer Rating               Industry  \
# 0                2016-07-31                3                  Dairy
# 1                2013-11-22                2           Auto Dealers
# ...

# %%
#tìm missing của bảng customer
df_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               100 non-null    object
#  1   Customer Name             100 non-null    object
#  2   Group ID                  100 non-null    object
#  3   Group Name                100 non-null    object
#  4   Relationship Established  100 non-null    datetime64[ns]
#  5   Customer Rating           100 non-null    int64
#  6   Industry                  100 non-null    object
#  7   Address                   100 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 6.4+ KB

# %% [markdown]
# => DataFrame không có missing

# %%
#Sử dụng hàm describe() để có các thống kê cơ bản về dữ liệu:
df_customer.describe()
# Out:
#        Customer Rating
# count       100.000000
# mean          2.500000
# std           0.958745
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           3.000000
# max           5.000000

# %%
#xóa cột không cần thiết trong bảng customer (Address)
columns = ['Address']
df_customer.drop(columns, inplace =True, axis=1)

# %%
#xuất ra bảng customer csv
df_customer.to_csv("D:\\mindxdata\\customer1.csv")

# %% [markdown]
# **XỬ LÍ BẢNG PRODUCT**

# %%
#đọc bảng product
df_product = pd.read_excel('D:\\mindxdata\\banking application\product-banking.xlsx')
df_product
# Out:
#    Product Group ID                  Product Name                 Type  \
# 0            PRD001                 Interest Only     Business Lending
# 1            PRD002            Business Overdraft            Overdraft
# 2            PRD003               Fixed Term Loan     Business Lending
# 3            PRD004           Wholesale Term Loan     Business Lending
# 4            PRD005           Personal Home Loans     Personal Lending
# 5            PRD006                 Finance Lease  Alternative Lending
# 6            PRD007                 Hire Purchase  Alternative Lending
# 7            PRD008       Gold Master Credit Card         Credit Cards
# 8            PRD009                Dealing Limits  Alternative Lending
# 9            PRD010         Gold Visa Credit Card         Credit Cards
# 10           PRD011        Trade Finance Currency        Trade Finance
# 11           PRD012                Bank Guarantee  Alternative Lending
# ...

# %%
#tìm missing của bảng product
df_product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Product Group ID   20 non-null     object
#  1   Product Name       20 non-null     object
#  2   Type               20 non-null     object
#  3   Currency           20 non-null     object
#  4   Current Ref. Rate  20 non-null     float64
#  5   Fixed or Floating  20 non-null     object
#  6   Payment Profile    20 non-null     int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 1.2+ KB

# %% [markdown]
# => DataFrame không có missing

# %%
#Sử dụng hàm describe() để có các thống kê cơ bản về dữ liệu:
df_product.describe()
# Out:
#        Current Ref. Rate  Payment Profile
# count          20.000000        20.000000
# mean            3.120500         1.700000
# std             0.358101         0.732695
# min             2.540000         1.000000
# 25%             2.832500         1.000000
# 50%             3.105000         2.000000
# 75%             3.407500         2.000000
# max             3.620000         3.000000

# %%
#xóa cột không cần thiết trong bảng product (Currency,Fixed or Floating,Payment Profile)  
columns = ['Currency','Payment Profile','Fixed or Floating']
df_product.drop(columns, inplace =True, axis=1)

# %%
#minitest để hiểu thêm về 25%,50%,75% trong describe()
xx = df_product.sort_values('Current Ref. Rate', ascending=True).reset_index(drop=1).drop(range(5,19))
xx.describe()
# Out:
#        Current Ref. Rate
# count           6.000000
# mean            2.801667
# std             0.409996
# min             2.540000
# 25%             2.580000
# 50%             2.655000
# 75%             2.752500
# max             3.620000

# %%
xx
# Out:
#    Product Group ID            Product Name                 Type  \
# 0            PRD007           Hire Purchase  Alternative Lending
# 1            PRD004     Wholesale Term Loan     Business Lending
# 2            PRD006           Finance Lease  Alternative Lending
# 3            PRD011  Trade Finance Currency        Trade Finance
# 4            PRD001           Interest Only     Business Lending
# 19           PRD020      Master Credit Card         Credit Cards
#
#     Current Ref. Rate
# 0                2.54
# 1                2.56
# 2                2.64
# 3                2.67
# 4                2.78
# 19               3.62

# %%
#xuất ra file csv để truy vấn dữ liệu SQL
df_product.to_csv("D:\\mindxdata\\product1.csv")

# %% [markdown]
# **XỬ LÍ BẢNG DETAILS BANKING**

# %%
#đọc file details-banking
df_details = pd.read_excel('D:\\mindxdata\\banking application\details-banking.xlsx')
df_details
# Out:
#    Relationship Manager ID Relationship Manager Bank Name       Branch Region  \
# 0                   RM2000         Victor Ramos    Bank 1   Western Australia
# 1                   RM2001      Mark Montgomery    Bank 1   Western Australia
# 2                   RM2002        Dennis Morris    Bank 1     New South Wales
# 3                   RM2003      Gregory Simmons    Bank 1            Victoria
# 4                   RM2004       Jeremy Vasquez    Bank 1  Northern Territory
# 5                   RM2005      Anthony Simpson    Bank 1   Western Australia
# 6                   RM2006        Ernest Rivera    Bank 1   Western Australia
# 7                   RM2007      Victor Martinez    Bank 1     New South Wales
# 8                   RM2008         Bobby Burton    Bank 1          Queensland
# 9                   RM2009         Bruce Porter    Bank 1     South Australia
# 10                  RM2010     Nicholas Simmons    Bank 1          Queensland
# ...

# %%
#tìm missing của bảng product
df_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Relationship Manager ID  41 non-null     object
#  1   Relationship Manager     41 non-null     object
#  2   Bank Name                41 non-null     object
#  3   Branch Region            41 non-null     object
#  4   Branch Name              41 non-null     object
# dtypes: object(5)
# memory usage: 1.7+ KB

# %% [markdown]
# => DataFrame không có missing

# %%
df_details.describe()
# Out:
#        Relationship Manager ID Relationship Manager Bank Name  \
# count                       41                   41        41
# unique                      41                   41         1
# top                     RM2000         Victor Ramos    Bank 1
# freq                         1                    1        41
#
#           Branch Region Branch Name
# count                41          41
# unique                7          33
# top     New South Wales      Albany
# freq                 14           3

# %%
#xóa cột không cần thiết trong bảng details (Bank Name)
columns = ['Bank Name']
df_details.drop(columns, inplace =True, axis=1)

# %%
#xuất ra file csv để truy vấn dữ liệu SQL
df_details.to_csv("D:\\mindxdata\\bankdetails.csv")
